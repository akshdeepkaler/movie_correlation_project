# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts configuration of the plots

# Read in the data
df = pd.read_csv(r'movies.csv')

# %%
# Lets look at the data
df = df.dropna()

# %%
# Missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df[df['budget'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
# Data Types for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data type
df['budget'] = df['budget'].astype('int64')
# Out:
# C:\Users\akshd\AppData\Local\Temp/ipykernel_23192/1075899108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['budget'] = df['budget'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df[['date of release', 'Country of Release']] = df["released"].apply(lambda x: pd.Series(str(x).split("(")))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# Drop columns
df.drop(['Country of Release', 'released'], axis = 1)
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
# corrct year column
df["Correct Year"]= df["date of release"].astype(str).str[-5:]
# Out:
# C:\Users\akshd\AppData\Local\Temp/ipykernel_23192/3896964960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Correct Year"]= df["date of release"].astype(str).str[-5:]

# %%
df.sort_values(by=['gross'], inplace = False, ascending = False).head()
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
#
#       released  score      votes  director  writer  star  country     budget  \
# 5445       527    7.8  1100000.0       785    1263  1534       47  237000000
# 7445       137    8.4   903000.0       105     513  1470       47  356000000
# 3045       534    7.8  1100000.0       785    1263  1073       47  200000000
# 6663       529    7.8   876000.0       768    1806   356       47  245000000
# 7244       145    8.4   897000.0       105     513  1470       47  321000000
#
#              gross  company  runtime  date of release  Country of Release  \
# ...

# %%
# Drop Duplicates
df['company'].drop_duplicates().sort_values(ascending= False).head()
# Out:
# 7129    1474
# 5664    1473
# 4007    1472
# 6793    1471
# 6420    1470
# Name: company, dtype: int16

# %%
# Scatter plot Budget vs Gross Revenue
plt.scatter(x=df['budget'], y=df['gross'])
plt.title("Budget vs Gross Earnings")
plt.ylabel('Gross Earnings')
plt.xlabel('Film Budget')
plt.show()

# %%
# Plot Budget vs gross using seaborn
sns.regplot(x='budget', y = 'gross', data =df, scatter_kws = {"color":"red"}, line_kws ={"color" : "green"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlation Plot
df.corr(method = 'pearson')
# Out:
#                       rating     genre      year  released     score  \
# rating              1.000000  0.147796  0.019499  0.018083  0.065983
# genre               0.147796  1.000000 -0.073167  0.022142  0.035106
# year                0.019499 -0.073167  1.000000 -0.001740  0.056386
# released            0.018083  0.022142 -0.001740  1.000000  0.045874
# score               0.065983  0.035106  0.056386  0.045874  1.000000
# votes               0.006031 -0.135990  0.206021  0.028833  0.474256
# director            0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer             -0.003149  0.017578 -0.025908  0.008072  0.012843
# star                0.009196  0.003341 -0.032157  0.015706  0.007296
# country             0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget             -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross              -0.181906 -0.244101  0.274321  0.008501  0.222556
# company            -0.092357 -0.071334 -0.014333 -0.002407  0.020656
# ...

# %%
correlation_matrix = df.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#                                              name  rating  genre  year  \
# 0                                     The Shining       6      6  1980
# 1                                 The Blue Lagoon       6      1  1980
# 2  Star Wars: Episode V - The Empire Strikes Back       4      0  1980
# 3                                       Airplane!       4      4  1980
# 4                                      Caddyshack       6      4  1980
#
#    released  score      votes  director  writer  star  country    budget  \
# 0      1304    8.4   927000.0      1795    2832   699       46  19000000
# 1      1127    5.8    65000.0      1578    1158   214       47   4500000
# 2      1359    8.7  1200000.0       757    1818  1157       47  18000000
# 3      1127    7.7   221000.0       889    1413  1474       47   3500000
# 4      1170    7.3   108000.0       719     351   271       47   6000000
#
#          gross  company  runtime  date of release  Country of Release  \
# ...

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show()

# %%
df_numerized.corr()
# Out:
#                       rating     genre      year  released     score  \
# rating              1.000000  0.147796  0.019499  0.018083  0.065983
# genre               0.147796  1.000000 -0.073167  0.022142  0.035106
# year                0.019499 -0.073167  1.000000 -0.001740  0.056386
# released            0.018083  0.022142 -0.001740  1.000000  0.045874
# score               0.065983  0.035106  0.056386  0.045874  1.000000
# votes               0.006031 -0.135990  0.206021  0.028833  0.474256
# director            0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer             -0.003149  0.017578 -0.025908  0.008072  0.012843
# star                0.009196  0.003341 -0.032157  0.015706  0.007296
# country             0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget             -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross              -0.181906 -0.244101  0.274321  0.008501  0.222556
# company            -0.092357 -0.071334 -0.014333 -0.002407  0.020656
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs.head()
# Out:
# rating  rating      1.000000
#         genre       0.147796
#         year        0.019499
#         released    0.018083
#         score       0.065983
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# budget  genre    -0.368523
# genre   budget   -0.368523
# gross   genre    -0.244101
# genre   gross    -0.244101
# budget  rating   -0.203946
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# votes               gross                 0.614751
# gross               votes                 0.614751
#                     budget                0.740247
# budget              gross                 0.740247
# year                Correct Year          0.998726
# Correct Year        year                  0.998726
# released            date of release       0.999951
# date of release     released              0.999951
# rating              rating                1.000000
# star                star                  1.000000
# date of release     date of release       1.000000
# runtime             runtime               1.000000
# company             company               1.000000
# gross               gross                 1.000000
# budget              budget                1.000000
# country             country               1.000000
# writer              writer                1.000000
# director            director              1.000000
# ...

# %% [markdown]
# # Votes and budget have the highest correlation to gross earnings
# ### Company has low correlation
